# %% [markdown]
# <a href="https://colab.research.google.com/github/nishantkumar1308/Cryptographic-Key-Generation/blob/main/Lorenz_Attractor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dt=0.01
num_steps=10000
xs=np.empty(num_steps+1);
ys=np.empty(num_steps+1);
zs=np.empty(num_steps+1);

xs[0]=0.1
ys[0]=1
zs[0]=1.05

s=10
r=28
b=2.667

for i in range (num_steps):
  xs[i+1]=xs[i]+(s*(ys[i]-xs[i]))*dt;
  ys[i+1]=ys[i]+(xs[i]*(r-zs[i])-ys[i])*dt;
  zs[i+1]=zs[i]+((xs[i]*ys[i]-b*zs[i]))*dt;

fig=plt.figure()
ax=fig.gca(projection='3d')
ax.plot(xs,ys,zs,lw=0.8)
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")
ax.set_title("Lorenz Attractor")
plt.show()
