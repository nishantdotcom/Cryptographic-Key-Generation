# %% [markdown]
# <a href="https://colab.research.google.com/github/nishantkumar1308/Cryptographic-Key-Generation/blob/main/NPCR_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
import cv2
import matplotlib.pyplot as plt
from io import BytesIO
from PIL import Image
import numpy as np
img = cv2.imread("cameraman.bmp")
img_cvt=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_cvt1=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img_cvt)
plt.show()

plt.imshow(img_cvt1)
plt.show()



print(img_cvt.shape)
# Out:
#      <input type="file" id="files-281a490c-8c90-4461-abfe-3dd17317012b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-281a490c-8c90-4461-abfe-3dd17317012b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cameraman.bmp to cameraman (2).bmp
# (256, 256, 3)

# %% [markdown]
# Here we will change the pixel value of one pixel

# %%
print(img_cvt[0][0])
# Out:
# [206 206 206]

# %%
print(img_cvt1[0][0])
# Out:
# [206 206 206]

# %%
img_cvt1[0][0]=10

# %%
print(img_cvt1[0][0])
# Out:
# [10 10 10]

# %%
plt.imshow(img_cvt1)
plt.show()

# %%
print(img_cvt[0][0])
# Out:
# [206 206 206]

# %%
plt.imshow(img_cvt1)
plt.show()
plt.imsave('cameraman2.bmp',img_cvt1)
print(img_cvt1[0][0])
# Out:
# [10 10 10]

# %% [markdown]
# WE start encrypting both images
# original and changed images to withstand NPCR test

# %%
def keygen(x,r,size):
  key=[]
  for i in range (size):
    x=r*x*(1-x)
    key.append(int(x*(pow(10,16))%256))
  return key

# %%
img = cv2.imread("cameraman.bmp")
img_cvt=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_cvt)
plt.show()
height=img_cvt.shape[0]
width=img_cvt.shape[1]
#height and width of image
#print(height)
#print(width)

#Generate  key for every  point of (256*256)image 

#key=keygen(0.01,3.95,height*width)
#print("Encryption key for every bit of image\n")
#print(key)


#Encryption key is generated and 

# print(img_cvt.shape)
key=keygen(0.01,3.95,height*width)
#Applying uisng Xor encryption algorithm
z=0
encrypt_image=np.zeros(shape=[height,width,3],dtype=np.uint8)
for i in range(height):
  for j in range(width):
    encrypt_image[i,j]=img_cvt[i,j]^key[z]
    z+=1



print("Encrypted image uisng chaotic key")
plt.imshow(encrypt_image)
plt.show()
plt.imsave('encrypt1.bmp',encrypt_image)
# Out:
# Encrypted image uisng chaotic key

# %%
img = cv2.imread("cameraman2.bmp")
img_cvt=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_cvt)
plt.show()
height=img_cvt.shape[0]
width=img_cvt.shape[1]
#height and width of image
#print(height)
#print(width)

#Generate  key for every  point of (256*256)image 

#key=keygen(0.01,3.95,height*width)
#print("Encryption key for every bit of image\n")
#print(key)


#Encryption key is generated and 

# print(img_cvt.shape)
key=keygen(0.01,3.95,height*width)
#Applying uisng Xor encryption algorithm
z=0
encrypt_image=np.zeros(shape=[height,width,3],dtype=np.uint8)
for i in range(height):
  for j in range(width):
    encrypt_image[i,j]=img_cvt[i,j]^key[z]
    z+=1



print("Encrypted image uisng chaotic key")
plt.imshow(encrypt_image)
plt.show()
plt.imsave('encrypt2.bmp',encrypt_image)
# Out:
# Encrypted image uisng chaotic key

# %% [markdown]
# Start Performing UACI TEST

# %%
  
    
 


img1 = cv2.imread("encrypt1.bmp")
img_cvt1=cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.imread("encrypt2.bmp")
img_cvt2=cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)


height=img1.shape[0]
width=img2.shape[1]
ans=0
# for y in range (height):
#  for x in range(width):

#     ans+=(abs(np.int64(img1[x,y])-np.int64(img2[x,y])))

 
# ans=(ans*100)/(height*width*225);
# print(ans);  
value=0 
for y in range(0,height):
        for x in range(0,width):
            value=(abs(img1[x,y][0]-img2[x,y][0])/255)+value

value=(value/(width*height))*100
print(value)
# Out:
# 0.0011728324142156864
